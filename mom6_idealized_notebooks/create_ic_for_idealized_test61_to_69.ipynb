# %%
import numpy as np
import matplotlib.pyplot as plt
from netCDF4 import Dataset
import os

# %%
from dask.distributed import Client
client = Client()
client
# Out:
# <Client: 'tcp://127.0.0.1:46207' processes=7 threads=7, memory=256.00 GiB>

# %% [markdown]
# ### Staggered grid (shared across all experiments)

# %%
Lx = 1000e3
Ly = 400e3
dx = 1000
dy = 1000
nx = int(Lx/dx)
ny = int(Ly/dy)
nxp = nx + 1
nyp = ny + 1

xh = np.linspace(dx/2, Lx - dx/2, nx)
yh = np.linspace(dy/2, Ly - dy/2, ny)
xq = np.linspace(0, Lx, nxp)
yq = np.linspace(0, Ly, nyp)

Xh, Yh   = np.meshgrid(xh, yh)
Xq, Yh_u = np.meshgrid(xq, yh)
Xh_v, Yq = np.meshgrid(xh, yq)

# %%
f = -1e-5
g = 9.81

# %% [markdown]
# ### Velocity profile — computed once, shared across all experiments
#
# All experiments (test61–test69) use the **same** tanh velocity profile and the **same** random noise realisation (fixed seed).

# %%
U    = 0.20
Ljet = 10e3
y0   = Ly / 2

yprime_h = (Yh   - y0) / Ljet
yprime_u = (Yh_u - y0) / Ljet
yprime_v = (Yq   - y0) / Ljet

u_clean = U * np.tanh(yprime_u)
v       = np.zeros((nyp, nx))

rng          = np.random.default_rng(seed=42)
random_noise = rng.standard_normal(u_clean.shape)
decay_factor = 1.0 / np.cosh(yprime_u)**2
noise        = 1e-3 * decay_factor * random_noise
u            = u_clean + noise

eta_t  = -(f * U * Ljet / g) * np.log(np.cosh(yprime_h))
eta_t -= eta_t.mean()

zl   = 1
z    = np.array([-250.0])
h_3d = eta_t[np.newaxis, :, :]
u_3d = u    [np.newaxis, :, :]
v_3d = v    [np.newaxis, :, :]

print('Velocity and eta fields computed - shared by all experiments.')
# Out:
# Velocity and eta fields computed - shared by all experiments.

# %% [markdown]
# ### Experiment loop — test61 to test69
#
# Replicates test52–60 but with an additional near-vertical drop to 1000 m immediately after the slope.
#
# **Bathymetry structure (same slope_start/end as test52-60):**
#
#
#
# | Experiment | Slope height (m) | Shelf (m) | After slope (m) | Abyss (m) |
# |------------|-----------------|-----------|-----------------|----------|
# | test61     | 25              | 100       | 125             | 1000     |
# | test62     | 50              | 100       | 150             | 1000     |
# | test63     | 100             | 100       | 200             | 1000     |
# | test64     | 150             | 100       | 250             | 1000     |
# | test65     | 200             | 100       | 300             | 1000     |
# | test66     | 250             | 100       | 350             | 1000     |
# | test67     | 300             | 100       | 400             | 1000     |
# | test68     | 350             | 100       | 450             | 1000     |
# | test69     | 375             | 100       | 475             | 1000     |

# %%
base_dir      = '/scratch/nm03/ae7501/mom6_input_directories/idealized'
shallow_depth = 100.0    # m - flat shelf
abyss_depth   = 1000.0   # m - deep flat basin beyond the 2-cell drop
slope_width   = 50       # grid cells (fixed, centred on cell 200)
slope_start   = 175      # 200 - 50//2
slope_end     = 225      # slope_start + slope_width
drop_start    = slope_end        # 2-cell drop begins immediately after slope
drop_end      = slope_end + 2   # 2 cells wide (near-vertical)

# Same slope heights as test52-60
slope_heights = [25, 50, 100, 150, 200, 250, 300, 350, 375]

experiments = [(61 + i, h) for i, h in enumerate(slope_heights)]

for exp_num, slope_height in experiments:

    exp_name   = f'test{exp_num}'
    input_dir  = os.path.join(base_dir, exp_name, 'INPUT')
    deep_depth = shallow_depth + slope_height   # depth at base of main slope

    os.makedirs(input_dir, exist_ok=True)

    print(f"\n{'='*60}")
    print(f' {exp_name}  |  slope_height={slope_height}m'
          f'  shelf={shallow_depth:.0f}m  after_slope={deep_depth:.0f}m  abyss={abyss_depth:.0f}m')

    # Bathymetry:
    #   [0          : slope_start] flat at shallow_depth (100m)
    #   [slope_start : slope_end ] linear drop: shallow_depth -> deep_depth
    #   [drop_start  : drop_end  ] 2-cell near-vertical drop: deep_depth -> abyss_depth
    #   [drop_end   :            ] flat at abyss_depth (1000m)
    depth_profile_y = np.zeros(ny)
    depth_profile_y[:slope_start]            = shallow_depth
    depth_profile_y[slope_start:slope_end]   = np.linspace(shallow_depth, deep_depth, slope_width)
    depth_profile_y[drop_start:drop_end]     = np.linspace(deep_depth, abyss_depth, 2)
    depth_profile_y[drop_end:]               = abyss_depth

    depth_2d = np.tile(depth_profile_y[:, np.newaxis], (1, nx))
    print(f' slope [{slope_start},{slope_end}): {shallow_depth:.0f}->{deep_depth:.0f}m  '
          f'drop [{drop_start},{drop_end}): {deep_depth:.0f}->1000m  '
          f'flat [{drop_end},400): 1000m')

    # --- init_vel.nc ---
    vel_path = os.path.join(input_dir, 'init_vel.nc')
    nc_vel = Dataset(vel_path, 'w', format='NETCDF4')
    nc_vel.createDimension('zl', zl)
    nc_vel.createDimension('yh', ny)
    nc_vel.createDimension('xh', nx)
    nc_vel.createDimension('yq', nyp)
    nc_vel.createDimension('xq', nxp)

    zl_v = nc_vel.createVariable('zl', 'f4', ('zl',))
    zl_v[:] = z ; zl_v.axis = 'Z' ; zl_v.long_name = 'depth to layer'

    xh_v = nc_vel.createVariable('xh', 'f4', ('xh',))
    xh_v[:] = xh ; xh_v.axis = 'X'
    xh_v.long_name = 'h-point longitude' ; xh_v.units = 'meters'

    yh_v = nc_vel.createVariable('yh', 'f4', ('yh',))
    yh_v[:] = yh ; yh_v.axis = 'Y'
    yh_v.long_name = 'h-point latitude' ; yh_v.units = 'meters'

    xq_v = nc_vel.createVariable('xq', 'f4', ('xq',))
    xq_v[:] = xq ; xq_v.axis = 'X'
    xq_v.long_name = 'q-point longitude' ; xq_v.units = 'meters'

    yq_v = nc_vel.createVariable('yq', 'f4', ('yq',))
    yq_v[:] = yq ; yq_v.axis = 'Y'
    yq_v.long_name = 'q-point latitude' ; yq_v.units = 'meters'

    u_var = nc_vel.createVariable('u', 'f4', ('zl', 'yh', 'xq'))
    u_var[:] = u_3d
    u_var.units = 'm s-1'
    u_var.long_name = 'Eastward velocity'
    u_var.standard_name = 'eastward_sea_water_velocity'

    v_var = nc_vel.createVariable('v', 'f4', ('zl', 'yq', 'xh'))
    v_var[:] = v_3d
    v_var.units = 'm s-1'
    v_var.long_name = 'Northward velocity'
    v_var.standard_name = 'northward_sea_water_velocity'

    nc_vel.regrid_method = 'bilinear'
    nc_vel.close()
    print(f' Written: {vel_path}')

    # --- init_eta.nc ---
    eta_path = os.path.join(input_dir, 'init_eta.nc')
    nc_h = Dataset(eta_path, 'w', format='NETCDF4')
    nc_h.createDimension('yh', ny)
    nc_h.createDimension('xh', nx)

    xh_v2 = nc_h.createVariable('xh', 'f4', ('xh',))
    xh_v2[:] = xh ; xh_v2.axis = 'X'
    xh_v2.long_name = 'h-point longitude' ; xh_v2.units = 'meters'

    yh_v2 = nc_h.createVariable('yh', 'f4', ('yh',))
    yh_v2[:] = yh ; yh_v2.axis = 'Y'
    yh_v2.long_name = 'h-point latitude' ; yh_v2.units = 'meters'

    h_var = nc_h.createVariable('eta_t', 'f4', ('yh', 'xh'))
    h_var[:] = h_3d
    h_var.units = 'm'
    h_var.long_name = 'Free surface height anomaly'
    h_var.standard_name = 'sea_floor_depth_below_sea_surface'

    nc_h.close()
    print(f' Written: {eta_path}')

    # --- ocean_topog.nc ---
    topo_path = os.path.join(input_dir, 'ocean_topog.nc')
    nc_d = Dataset(topo_path, 'w', format='NETCDF4')
    nc_d.createDimension('yh', ny)
    nc_d.createDimension('xh', nx)

    xh_d = nc_d.createVariable('xh', 'f4', ('xh',))
    xh_d[:] = xh
    xh_d.long_name = 't-cell center x-location' ; xh_d.units = 'meters'

    yh_d = nc_d.createVariable('yh', 'f4', ('yh',))
    yh_d[:] = yh
    yh_d.long_name = 't-cell center y-location' ; yh_d.units = 'meters'

    depth_var = nc_d.createVariable('depth', 'f4', ('yh', 'xh'))
    depth_var[:] = depth_2d
    depth_var.units = 'm'
    depth_var.long_name = 'ocean bottom depth'
    depth_var.standard_name = 'sea_floor_depth_below_geoid'

    nc_d.close()
    print(f' Written: {topo_path}')

print(f"\n{'='*60}")
print('All 9 experiments written successfully (test61-test69).')
print(f"{'='*60}")
# Out:
# ============================================================
#  test61  |  slope_height=25m  shelf=100m  after_slope=125m  abyss=1000m
#  slope [175,225): 100->125m  drop [225,227): 125->1000m  flat [227,400): 1000m
#  Written: /scratch/nm03/ae7501/mom6_input_directories/idealized/test61/INPUT/init_vel.nc
#  Written: /scratch/nm03/ae7501/mom6_input_directories/idealized/test61/INPUT/init_eta.nc
#  Written: /scratch/nm03/ae7501/mom6_input_directories/idealized/test61/INPUT/ocean_topog.nc
#
# ============================================================
#  test62  |  slope_height=50m  shelf=100m  after_slope=150m  abyss=1000m
#  slope [175,225): 100->150m  drop [225,227): 150->1000m  flat [227,400): 1000m
#  Written: /scratch/nm03/ae7501/mom6_input_directories/idealized/test62/INPUT/init_vel.nc
#  Written: /scratch/nm03/ae7501/mom6_input_directories/idealized/test62/INPUT/init_eta.nc
#  Written: /scratch/nm03/ae7501/mom6_input_directories/idealized/test62/INPUT/ocean_topog.nc
#
# ============================================================
#  test63  |  slope_height=100m  shelf=100m  after_slope=200m  abyss=1000m
#  slope [175,225): 100->200m  drop [225,227): 200->1000m  flat [227,400): 1000m
#  Written: /scratch/nm03/ae7501/mom6_input_directories/idealized/test63/INPUT/init_vel.nc
#  Written: /scratch/nm03/ae7501/mom6_input_directories/idealized/test63/INPUT/init_eta.nc
#  Written: /scratch/nm03/ae7501/mom6_input_directories/idealized/test63/INPUT/ocean_topog.nc
#
# ============================================================
#  test64  |  slope_height=150m  shelf=100m  after_slope=250m  abyss=1000m
#  slope [175,225): 100->250m  drop [225,227): 250->1000m  flat [227,400): 1000m
#  Written: /scratch/nm03/ae7501/mom6_input_directories/idealized/test64/INPUT/init_vel.nc
#  Written: /scratch/nm03/ae7501/mom6_input_directories/idealized/test64/INPUT/init_eta.nc
#  Written: /scratch/nm03/ae7501/mom6_input_directories/idealized/test64/INPUT/ocean_topog.nc
#
# ============================================================
#  test65  |  slope_height=200m  shelf=100m  after_slope=300m  abyss=1000m
#  slope [175,225): 100->300m  drop [225,227): 300->1000m  flat [227,400): 1000m
#  Written: /scratch/nm03/ae7501/mom6_input_directories/idealized/test65/INPUT/init_vel.nc
#  Written: /scratch/nm03/ae7501/mom6_input_directories/idealized/test65/INPUT/init_eta.nc
#  Written: /scratch/nm03/ae7501/mom6_input_directories/idealized/test65/INPUT/ocean_topog.nc
#
# ============================================================
#  test66  |  slope_height=250m  shelf=100m  after_slope=350m  abyss=1000m
#  slope [175,225): 100->350m  drop [225,227): 350->1000m  flat [227,400): 1000m
#  Written: /scratch/nm03/ae7501/mom6_input_directories/idealized/test66/INPUT/init_vel.nc
#  Written: /scratch/nm03/ae7501/mom6_input_directories/idealized/test66/INPUT/init_eta.nc
#  Written: /scratch/nm03/ae7501/mom6_input_directories/idealized/test66/INPUT/ocean_topog.nc
#
# ============================================================
#  test67  |  slope_height=300m  shelf=100m  after_slope=400m  abyss=1000m
#  slope [175,225): 100->400m  drop [225,227): 400->1000m  flat [227,400): 1000m
#  Written: /scratch/nm03/ae7501/mom6_input_directories/idealized/test67/INPUT/init_vel.nc
#  Written: /scratch/nm03/ae7501/mom6_input_directories/idealized/test67/INPUT/init_eta.nc
#  Written: /scratch/nm03/ae7501/mom6_input_directories/idealized/test67/INPUT/ocean_topog.nc
#
# ============================================================
#  test68  |  slope_height=350m  shelf=100m  after_slope=450m  abyss=1000m
#  slope [175,225): 100->450m  drop [225,227): 450->1000m  flat [227,400): 1000m
#  Written: /scratch/nm03/ae7501/mom6_input_directories/idealized/test68/INPUT/init_vel.nc
#  Written: /scratch/nm03/ae7501/mom6_input_directories/idealized/test68/INPUT/init_eta.nc
#  Written: /scratch/nm03/ae7501/mom6_input_directories/idealized/test68/INPUT/ocean_topog.nc
#
# ============================================================
#  test69  |  slope_height=375m  shelf=100m  after_slope=475m  abyss=1000m
#  slope [175,225): 100->475m  drop [225,227): 475->1000m  flat [227,400): 1000m
#  Written: /scratch/nm03/ae7501/mom6_input_directories/idealized/test69/INPUT/init_vel.nc
#  Written: /scratch/nm03/ae7501/mom6_input_directories/idealized/test69/INPUT/init_eta.nc
#  Written: /scratch/nm03/ae7501/mom6_input_directories/idealized/test69/INPUT/ocean_topog.nc
#
# ============================================================
# All 9 experiments written successfully (test61-test69).
# ============================================================

# %% [markdown]
# ### check plot — bathymetry profiles for all experiments

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 5))
colors = plt.cm.plasma(np.linspace(0.1, 0.9, len(experiments)))

for ax, xlim, title_suffix in zip(
        axes,
        [(150, 280), (0, 400)],
        ['(zoomed around slope and drop)', '(full domain)']):

    for i, (exp_num, slope_height) in enumerate(experiments):
        deep_depth = shallow_depth + slope_height

        profile = np.zeros(ny)
        profile[:slope_start]          = shallow_depth
        profile[slope_start:slope_end] = np.linspace(shallow_depth, deep_depth, slope_width)
        profile[drop_start:drop_end]   = np.linspace(deep_depth, abyss_depth, 2)
        profile[drop_end:]             = abyss_depth

        ax.plot(np.arange(ny), profile, color=colors[i],
                label=f'test{exp_num}  dh={slope_height}m')

    ax.axvline(slope_start, color='k',    linestyle=':',  linewidth=0.8, label=f'slope start ({slope_start})')
    ax.axvline(slope_end,   color='k',    linestyle='--', linewidth=0.8, label=f'slope end / drop start ({slope_end})')
    ax.axvline(drop_end,    color='gray', linestyle='--', linewidth=0.8, label=f'drop end ({drop_end})')
    ax.set_xlim(xlim)
    ax.set_xlabel('ny index')
    ax.set_ylabel('Depth (m)')
    ax.invert_yaxis()
    ax.set_title(f'Bathymetry — test61 to test69\n{title_suffix}')
    ax.grid(True, alpha=0.3)

axes[0].legend(loc='lower right', fontsize=8)
plt.tight_layout()
plt.show()
