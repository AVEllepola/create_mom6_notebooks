# %% [markdown]
# # Setting up a restart file for regional dye tracer in MOM6

# %% [markdown]
# *Goal* : Including dye tracers in a MOM6 run that would be continued from a restart point.
#
# *Requirements* : The tracer is expected to behave as a passive tracers that is released along the shore lines similiar to how cholorophyl blooms appear along she shlef regions. Higher concentrations along the shore and reducing concentration cross shelf.
#
# *Whats needed* : A working MOM6 experiment setup, a compiled MOM6 model to run the experiment.

# %% [raw]
# Tracers in MOM6: MOM6 has several inbuilt tracer packages that could be used. Some of the tracer packages has the capability to run from any point of the run without having a restart file. These are the packages where the code is made so the tracer would automatically initialize when a restart file is not found (e.g. BOUNDARY IMPULSE TRACER). This notebook is made to create a restart file for the REGIONAL_DYE, which either needs to be included at the initialization of the model or have a restart file to continue the run.
#
# Following fields should be included in the <MOM_Input> file to have the dye tracer working in the model.
#
# In this example one tracer is released from an area defined by the min,max coordinates.
#
# ! === module MOM_tracer_flow_control ===
# USE_REGIONAL_DYES = True
# NUM_DYE_TRACERS = 1
# ! === module segment_tracer_registry_init ===
# DYE_SOURCE_MINLON = 122
# DYE_SOURCE_MAXLON = 122.5
# DYE_SOURCE_MINLAT = -16.5
# DYE_SOURCE_MAXLAT = -16
# DYE_SOURCE_MINDEPTH = 0.0
# DYE_SOURCE_MAXDEPTH = 10.0
#
# The diags related to regional dye tracer could be found in available_diags.000000
#
# below is an example of a diagnosis used in the daig_table
#
# "ocean_model",   "dye001",          "dye01",              "ocean_hourly",         "all", "mean", "none",2

# %% [markdown]
# A restart file is needed to include the dye tracer into the existing experiment. Since you would want your restart file to have the grid correct, easiest way is to copy an existing resatrt file from a diferent tracer (salt,temp,etc..) and rewrite the atributes and values as needed.
#
# To make sure I have all the attributes and the grid correct, I made a duplicate of my MOM6 run directory and ran from intialization with the Regional Dye included for few hours. This creates a restart file for the dye tracer. Then I change the vlaues in this restart file to represent the dye as per the requirement. Finally newly made/edited restart file is copied to the restart folder of the Original MOM6 run that I wish to continue.
#
# **Some of the restart files in the restart folder needs to be renamed since we are changing the number of restart files in the folder and disrupting the existing order of the files.**
#
# MOM6 restart files are named in the format of MOM.res_<no>.nc . The restart file for the dye tracer was MOM.res_11.nc in my experiment setup (not sure how the numbering would k for a different setup.)

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import netCDF4 as nc
import xarray as xr
import cmocean as cm
from dask.distributed import Client

# %%
client = Client()
client
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/distributed/node.py:187: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 37583 instead
#   warnings.warn(
# <Client: 'tcp://127.0.0.1:38343' processes=7 threads=28, memory=126.00 GiB>
# 2025-06-08 07:42:54,083 - distributed.nanny - WARNING - Restarting worker
# 2025-06-08 07:42:54,086 - distributed.nanny - WARNING - Restarting worker
# 2025-06-08 07:42:54,094 - distributed.nanny - WARNING - Restarting worker
# 2025-06-08 07:42:54,101 - distributed.nanny - WARNING - Restarting worker
# 2025-06-08 07:42:54,108 - distributed.nanny - WARNING - Restarting worker
# 2025-06-08 07:42:54,115 - distributed.nanny - WARNING - Restarting worker
# 2025-06-08 07:42:54,122 - distributed.nanny - WARNING - Restarting worker
# 2025-06-08 07:42:54,152 - distributed.nanny - WARNING - Restarting worker
# 2025-06-08 07:42:54,155 - distributed.nanny - WARNING - Restarting worker
# 2025-06-08 07:42:54,161 - distributed.nanny - WARNING - Restarting worker
# 2025-06-08 07:42:54,166 - distributed.nanny - WARNING - Restarting worker
# 2025-06-08 07:42:54,173 - distributed.nanny - WARNING - Restarting worker
# 2025-06-08 07:42:54,179 - distributed.nanny - WARNING - Restarting worker
# 2025-06-08 07:42:54,186 - distributed.nanny - WARNING - Restarting worker
# 2025-06-08 07:42:54,264 - distributed.nanny - WARNING - Restarting worker
# 2025-06-08 07:42:54,267 - distributed.nanny - WARNING - Restarting worker
# 2025-06-08 07:42:54,271 - distributed.nanny - WARNING - Restarting worker
# 2025-06-08 07:42:54,275 - distributed.nanny - WARNING - Restarting worker
# 2025-06-08 07:42:54,281 - distributed.nanny - WARNING - Restarting worker
# 2025-06-08 07:42:54,286 - distributed.nanny - WARNING - Restarting worker
# 2025-06-08 07:42:54,291 - distributed.nanny - WARNING - Restarting worker
# 2025-06-08 07:42:54,575 - distributed.nanny - WARNING - Restarting worker
# 2025-06-08 07:42:54,578 - distributed.nanny - WARNING - Restarting worker
# 2025-06-08 07:42:54,584 - distributed.nanny - WARNING - Restarting worker
# 2025-06-08 07:42:54,588 - distributed.nanny - WARNING - Restarting worker
# 2025-06-08 07:42:54,593 - distributed.nanny - WARNING - Restarting worker
# 2025-06-08 07:42:54,598 - distributed.nanny - WARNING - Restarting worker
# 2025-06-08 07:42:54,603 - distributed.nanny - WARNING - Restarting worker
# 2025-06-08 07:42:55,588 - distributed.nanny - WARNING - Restarting worker
# 2025-06-08 07:42:55,593 - distributed.nanny - WARNING - Restarting worker
# 2025-06-08 07:42:55,599 - distributed.nanny - WARNING - Restarting worker
# 2025-06-08 07:42:55,606 - distributed.nanny - WARNING - Restarting worker
# 2025-06-08 07:42:55,611 - distributed.nanny - WARNING - Restarting worker
# 2025-06-08 07:42:55,896 - distributed.nanny - WARNING - Restarting worker
# 2025-06-08 07:42:55,903 - distributed.nanny - WARNING - Restarting worker

# %% [markdown]
# ### Open the restart file from the duplicate MOM6 run

# %%
MOM_restart = xr.open_dataset('/scratch/nm03/ae7501/mom6/archive/kimberly-reanalysis24/restart020/MOM.res_11.nc', decode_times=False) # xr will try to decode the time dimention and fail if decode_time= false is not set. time value in the restart file does not mathc the np date time setup.

# %%
MOM_restart
# Out:
# <xarray.Dataset> Size: 3GB
# Dimensions:  (lath: 1285, lonh: 2611, Layer: 100, Time: 1)
# Coordinates:
#   * lath     (lath) float64 10kB -28.99 -28.97 -28.96 ... -7.043 -7.026 -7.009
#   * lonh     (lonh) float64 21kB 96.01 96.03 96.05 96.06 ... 143.0 143.0 143.0
#   * Layer    (Layer) float64 800B 2.465 7.407 12.37 ... 4.857e+03 5.452e+03
#   * Time     (Time) float64 8B 7.388e+05
# Data variables:
#     dye001   (Time, Layer, lath, lonh) float64 3GB ...
# Attributes:
#     NumFilesInSet:  1

# %%
dye_restart = MOM_restart.dye001
dye_restart
# Out:
# <xarray.DataArray 'dye001' (Time: 1, Layer: 100, lath: 1285, lonh: 2611)> Size: 3GB
# [335513500 values with dtype=float64]
# Coordinates:
#   * lath     (lath) float64 10kB -28.99 -28.97 -28.96 ... -7.043 -7.026 -7.009
#   * lonh     (lonh) float64 21kB 96.01 96.03 96.05 96.06 ... 143.0 143.0 143.0
#   * Layer    (Layer) float64 800B 2.465 7.407 12.37 ... 4.857e+03 5.452e+03
#   * Time     (Time) float64 8B 7.388e+05
# Attributes:
#     long_name:  Dye Tracer 001
#     units:      conc
#     checksum:   F8D71A734118F22D

# %%
print(np.isnan(MOM_restart.dye001).any())
# no nans
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(np.isnan(MOM_restart.dye001).any())
#       2 # no nans
#
# NameError: name 'np' is not defined

# %%
MOM_restart.dye001.isel(Time=0, Layer=0).plot(robust=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 MOM_restart.dye001.isel(Time=0, Layer=0).plot(robust=True)
#
# NameError: name 'MOM_restart' is not defined

# %% [markdown]
# ### Open the ocean stat file to create tracer data based on bathymentry

# %% [markdown]
# As my requirment was to spread the dye in a manner that looks like a chloropyl bloom, I use my bathymetry to recreate that spread.

# %%
ocean_stat = xr.open_dataset('/scratch/nm03/ae7501/mom6/archive/kimberly-reanalysis24/output000/20230202.ocean_static.nc')
ocean_stat.deptho.plot(robust=True)

# %% [markdown]
# Change the values of the dye restart file to reflect the values from bathymetry

# %%
# The values of bathymetry are copied to all layers of the dye tracer restart.
for i in range(dye_restart.sizes["Layer"]):
  MOM_restart.dye001.data[0, i, ...] = ocean_stat.deptho

# %%
MOM_restart.dye001

# %% [markdown]
# normalize the values of the restart between 1 and 0

# %% [markdown]
# Next the dye concentration values needs to be between 0 and 1. Therefore the copied bathymetry values are normalized between 1 and 0.

# %%
def normalize_xarray(var):
    var_min = var.min()  # Minimum value
    var_max = var.max()  # Maximum value

    normalized_var = (var - var_min) / (var_max - var_min)  # Scale between 0 and 1
    return normalized_var

# Example usage:
normalized_var = 1-normalize_xarray(MOM_restart.dye001)

# %%
MOM_restart.dye001.values = normalized_var.values
MOM_restart.dye001.isel(Time=0,Layer=0).plot(robust =True)

# %% [markdown]
# add an exponential decay to the values to have higher concentration closer to the shore line and have lesser concentration as moving closer to the shelbreak

# %%
def exponential_decay(var, k):
    """Applies an exponential decay where values drop exponentially 
    as they move away from the max value.
    
    Parameters:
    - var: xarray.DataArray (the variable to normalize)
    - k: float (controls how fast values drop; higher values decay faster)
    
    Returns:
    - exponential_decay_var xarray.DataArray (values between 0 and 1)
    """
    var_max = var.max()
    
    # Apply exponential decay function
    exponential_decay_var = np.exp(-k * (var_max - var))
    
    return exponential_decay_var

# Example usage:
exponential_decay_var = exponential_decay(MOM_restart.dye001, k=15)  # Adjust k for desired decay

# %%
MOM_restart.dye001.values = exponential_decay_var.values
MOM_restart.dye001.isel(Time=0,Layer=0).plot(robust =True)

# %%
MOM_restart["dye001"] = MOM_restart["dye001"].fillna(0) # nan values cause the model to break. land mask is applied seperately during the model run. fill all nans with 0

# %%
MOM_restart.dye001.isel(Time=0,Layer=0).plot(robust =True)

# %% [markdown]
# We need to change the time value of the newly created tracer restart file to match that of the restart files in the MOM6 restart folder that will be used to run the experiment.
# i.e. adjust the time stamp to mathch the restart point.

# %%
MOM_restart_1= xr.open_dataset('/scratch/nm03/ae7501/mom6/archive/kimberly-reanalysis20/restart036/MOM.res_1.nc', decode_times=False) # opena random restart file from the original experiment setup

# %%
MOM_restart_1
# Out:
# <xarray.Dataset> Size: 3GB
# Dimensions:  (lath: 1285, lonh: 2611, Layer: 100, Time: 1)
# Coordinates:
#   * lath     (lath) float64 10kB -28.99 -28.97 -28.96 ... -7.043 -7.026 -7.009
#   * lonh     (lonh) float64 21kB 96.01 96.03 96.05 96.06 ... 143.0 143.0 143.0
#   * Layer    (Layer) float64 800B 2.465 7.407 12.37 ... 4.857e+03 5.452e+03
#   * Time     (Time) float64 8B 7.389e+05
# Data variables:
#     Salt     (Time, Layer, lath, lonh) float64 3GB ...
# Attributes:
#     NumFilesInSet:  1

# %%
MOM_restart["Time"] = MOM_restart_1["Time"]

# %%
MOM_restart
# Out:
# <xarray.Dataset> Size: 3GB
# Dimensions:  (lath: 1285, lonh: 2611, Layer: 100, Time: 1)
# Coordinates:
#   * lath     (lath) float64 10kB -28.99 -28.97 -28.96 ... -7.043 -7.026 -7.009
#   * lonh     (lonh) float64 21kB 96.01 96.03 96.05 96.06 ... 143.0 143.0 143.0
#   * Layer    (Layer) float64 800B 2.465 7.407 12.37 ... 4.857e+03 5.452e+03
#   * Time     (Time) float64 8B 7.389e+05
# Data variables:
#     dye001   (Time, Layer, lath, lonh) float64 3GB 0.000324 0.0003254 ... 0.0
# Attributes:
#     NumFilesInSet:  1

# %% [markdown]
# ### save the newly created restart nc file

# %%
MOM_restart.to_netcdf('/scratch/nm03/ae7501/mom6/archive/kimberly-reanalysis20/restart036/MOM.res_new.nc') #this file needs to be renamed as MOM.res_11.nc .

# %% [markdown]
# Lets check if the file is properly saved

# %%
MOM_restart_chk= xr.open_dataset('/scratch/nm03/ae7501/mom6/archive/kimberly-reanalysis20/restart036/MOM.res_new.nc', decode_times=False)

# %%
MOM_restart_chk
# Out:
# <xarray.Dataset> Size: 3GB
# Dimensions:  (lath: 1285, lonh: 2611, Layer: 100, Time: 1)
# Coordinates:
#   * lath     (lath) float64 10kB -28.99 -28.97 -28.96 ... -7.043 -7.026 -7.009
#   * lonh     (lonh) float64 21kB 96.01 96.03 96.05 96.06 ... 143.0 143.0 143.0
#   * Layer    (Layer) float64 800B 2.465 7.407 12.37 ... 4.857e+03 5.452e+03
#   * Time     (Time) float64 8B 7.389e+05
# Data variables:
#     dye001   (Time, Layer, lath, lonh) float64 3GB ...
# Attributes:
#     NumFilesInSet:  1

# %%
MOM_restart_chk.dye001.isel(Time=0, Layer=0).plot(robust=True)

# %%
print(np.isnan(MOM_restart_chk.dye001).any())
# Out:
# <xarray.DataArray 'dye001' ()> Size: 1B
# array(False)
